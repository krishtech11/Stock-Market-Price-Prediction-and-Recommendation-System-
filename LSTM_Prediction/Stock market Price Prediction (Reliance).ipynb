# %%
# Importing all the Libraries

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import openpyxl as op # To read and write excel file
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
from tensorflow import keras as k
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.utils import plot_model
from keras.models import load_model

# %%
# Get the Dataset or Reading the  dataset from the csv file/excel sheet

stock_data = pd.read_excel("datasets/reliance.xlsx")

# %%
# Checking the Dataset

stock_data.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close  \
# 0 1996-01-01  15.859429  15.944529  15.754989  15.917452  10.477991
# 1 1996-01-02  15.878770  15.956133  15.677626  15.793671  10.396512
# 2 1996-01-03  16.052837  16.783918  15.878770  15.913584  10.475444
# 3 1996-01-04  15.762726  15.813012  15.553845  15.766594  10.378685
# 4 1996-01-05  15.704703  15.704703  15.522900  15.658285  10.307391
#
#         Volume
# 0   48051995.0
# 1   77875009.0
# 2   96602936.0
# 3  100099436.0
# 4   76935930.0

# %%
#Displaying the structure of the dataset

stock_data.shape
# Out:
# (6715, 7)

# %%
# Check for the type of data 

stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6715 entries, 0 to 6714
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6715 non-null   datetime64[ns]
#  1   Open       6705 non-null   float64
#  2   High       6705 non-null   float64
#  3   Low        6705 non-null   float64
#  4   Close      6705 non-null   float64
#  5   Adj Close  6705 non-null   float64
#  6   Volume     6705 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 367.4 KB

# %%
#Check for the Null- Values

stock_data.isnull().sum()
# Out:
# Date          0
# Open         10
# High         10
# Low          10
# Close        10
# Adj Close    10
# Volume       10
# dtype: int64

# %%
#dropping the rows of the null values

stock_data.dropna()

#Filling the null values with 0

stock_data.fillna(0)

#Replacing the Null values with mean of the column

stock_data['Open'].fillna(value=stock_data['Open'].mean(),inplace=True)
stock_data['High'].fillna(value=stock_data['High'].mean(),inplace=True)
stock_data['Low'].fillna(value=stock_data['Low'].mean(),inplace=True)
stock_data['Close'].fillna(value=stock_data['Close'].mean(),inplace=True)
stock_data['Adj Close'].fillna(value=stock_data['Adj Close'].mean(),inplace=True)
stock_data['Volume'].fillna(value=stock_data['Volume'].mean(),inplace=True)

# %%
#plot the True Adj Close value
plt.xlabel('Date')
plt.ylabel('Adj Close Price')
plt.gca().yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))
plt.gca().xaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))
stock_data['Adj Close'].plot()
# Out:
# <Axes: xlabel='Date', ylabel='Adj Close Price'>

# %%
#Set Target variable

output_var=pd.DataFrame(stock_data['Adj Close'])

#selecting the Features

features=['Open','High','Low','Volume']

# %%
#Scaling

scaler=MinMaxScaler()
feature_transform = scaler.fit_transform(stock_data[features])
feature_transform= pd.DataFrame(columns=features, data=feature_transform, index=stock_data.index)
feature_transform.head()
# Out:
#        Open      High       Low    Volume
# 0  0.001414  0.001425  0.001439  0.071863
# 1  0.001421  0.001429  0.001411  0.116464
# 2  0.001482  0.001720  0.001483  0.144472
# 3  0.001380  0.001379  0.001366  0.149701
# 4  0.001360  0.001341  0.001355  0.115060

# %%
#Splitting to Training set and Test set

timesplit= TimeSeriesSplit(n_splits=10)
for train_index, test_index in timesplit.split(feature_transform):
    X_train, X_test = feature_transform[:len(train_index)], feature_transform[len(train_index): (len(train_index)+len(test_index))]
    y_train, y_test = output_var[:len(train_index)].values.ravel(), output_var[len(train_index): (len(train_index)+len(test_index))].values.ravel()

# %%
#Process the data For LSTM

trainX =np.array(X_train)
testX =np.array(X_test)
X_train = trainX.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = testX.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
#Building the LSTM Model

lstm = Sequential()
lstm.add(LSTM(32, input_shape=(1, trainX.shape[1]), activation='relu', return_sequences=False))
lstm.add(Dense(1))
lstm.compile(loss='mean_squared_error', optimizer='adam')
plot_model(lstm, show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
# Model Training 

history=lstm.fit(X_train, y_train, epochs=100, batch_size=8, verbose=1, shuffle=False)
# Out:
# Epoch 1/100
# 764/764 [==============================] - 2s 2ms/step - loss: 201322.7656
# Epoch 2/100
# 764/764 [==============================] - 1s 1ms/step - loss: 167659.0781
# Epoch 3/100
# 764/764 [==============================] - 1s 1ms/step - loss: 136324.5469
# Epoch 4/100
# 764/764 [==============================] - 1s 1ms/step - loss: 109371.3594
# Epoch 5/100
# 764/764 [==============================] - 1s 1ms/step - loss: 88614.9766
# Epoch 6/100
# 764/764 [==============================] - 1s 1ms/step - loss: 73530.3672
# Epoch 7/100
# 764/764 [==============================] - 1s 1ms/step - loss: 61907.2148
# Epoch 8/100
# 764/764 [==============================] - 1s 1ms/step - loss: 51265.5742
# Epoch 9/100
# 764/764 [==============================] - 1s 1ms/step - loss: 40285.6953
# Epoch 10/100
# 764/764 [==============================] - 1s 1ms/step - loss: 29525.4746
# Epoch 11/100
# 764/764 [==============================] - 2s 2ms/step - loss: 20410.9863
# Epoch 12/100
# 764/764 [==============================] - 1s 1ms/step - loss: 13612.6797
# Epoch 13/100
# 764/764 [==============================] - 1s 1ms/step - loss: 8881.9580
# Epoch 14/100
# 764/764 [==============================] - 1s 1ms/step - loss: 5758.9062
# Epoch 15/100
# 764/764 [==============================] - 1s 1ms/step - loss: 3819.6667
# Epoch 16/100
# 764/764 [==============================] - 1s 1ms/step - loss: 2659.8540
# Epoch 17/100
# 764/764 [==============================] - 1s 1ms/step - loss: 1991.9918
# Epoch 18/100
# 764/764 [==============================] - 1s 1ms/step - loss: 1603.5509
# Epoch 19/100
# 764/764 [==============================] - 1s 1ms/step - loss: 1362.1550
# Epoch 20/100
# 764/764 [==============================] - 1s 1ms/step - loss: 1198.2510
# Epoch 21/100
# 764/764 [==============================] - 1s 1ms/step - loss: 1079.4409
# Epoch 22/100
# 764/764 [==============================] - 1s 1ms/step - loss: 988.6641
# Epoch 23/100
# 764/764 [==============================] - 1s 1ms/step - loss: 917.4241
# Epoch 24/100
# 764/764 [==============================] - 1s 1ms/step - loss: 860.8805
# Epoch 25/100
# 764/764 [==============================] - 1s 1ms/step - loss: 814.1519
# Epoch 26/100
# 764/764 [==============================] - 1s 1ms/step - loss: 774.1713
# Epoch 27/100
# 764/764 [==============================] - 1s 1ms/step - loss: 738.9102
# Epoch 28/100
# 764/764 [==============================] - 1s 1ms/step - loss: 707.1040
# Epoch 29/100
# 764/764 [==============================] - 1s 1ms/step - loss: 678.6300
# Epoch 30/100
# 764/764 [==============================] - 1s 1ms/step - loss: 652.5759
# Epoch 31/100
# 764/764 [==============================] - 1s 1ms/step - loss: 628.0053
# Epoch 32/100
# 764/764 [==============================] - 1s 1ms/step - loss: 604.9876
# Epoch 33/100
# 764/764 [==============================] - 1s 1ms/step - loss: 583.7220
# Epoch 34/100
# 764/764 [==============================] - 1s 1ms/step - loss: 563.2825
# Epoch 35/100
# 764/764 [==============================] - 1s 2ms/step - loss: 543.5391
# Epoch 36/100
# 764/764 [==============================] - 1s 2ms/step - loss: 524.5223
# Epoch 37/100
# 764/764 [==============================] - 2s 2ms/step - loss: 505.8771
# Epoch 38/100
# 764/764 [==============================] - 1s 1ms/step - loss: 487.5963
# Epoch 39/100
# 764/764 [==============================] - 1s 1ms/step - loss: 469.5505
# Epoch 40/100
# 764/764 [==============================] - 1s 1ms/step - loss: 451.6548
# Epoch 41/100
# 764/764 [==============================] - 1s 1ms/step - loss: 433.8559
# Epoch 42/100
# 764/764 [==============================] - 1s 1ms/step - loss: 416.1414
# Epoch 43/100
# 764/764 [==============================] - 1s 1ms/step - loss: 398.4499
# Epoch 44/100
# 764/764 [==============================] - 1s 1ms/step - loss: 380.8653
# Epoch 45/100
# 764/764 [==============================] - 1s 1ms/step - loss: 363.2693
# Epoch 46/100
# 764/764 [==============================] - 1s 1ms/step - loss: 345.7982
# Epoch 47/100
# 764/764 [==============================] - 1s 1ms/step - loss: 328.3795
# Epoch 48/100
# 764/764 [==============================] - 1s 1ms/step - loss: 311.0711
# Epoch 49/100
# 764/764 [==============================] - 1s 1ms/step - loss: 293.9074
# Epoch 50/100
# 764/764 [==============================] - 1s 1ms/step - loss: 276.9389
# Epoch 51/100
# 764/764 [==============================] - 1s 1ms/step - loss: 260.2270
# Epoch 52/100
# 764/764 [==============================] - 1s 1ms/step - loss: 243.8450
# Epoch 53/100
# 764/764 [==============================] - 1s 1ms/step - loss: 227.8766
# Epoch 54/100
# 764/764 [==============================] - 1s 1ms/step - loss: 212.4113
# Epoch 55/100
# 764/764 [==============================] - 1s 1ms/step - loss: 197.5414
# Epoch 56/100
# 764/764 [==============================] - 1s 1ms/step - loss: 183.3819
# Epoch 57/100
# 764/764 [==============================] - 1s 1ms/step - loss: 169.9569
# Epoch 58/100
# 764/764 [==============================] - 1s 1ms/step - loss: 157.3874
# Epoch 59/100
# 764/764 [==============================] - 1s 1ms/step - loss: 145.6863
# Epoch 60/100
# 764/764 [==============================] - 1s 1ms/step - loss: 134.9128
# Epoch 61/100
# 764/764 [==============================] - 1s 1ms/step - loss: 125.0691
# Epoch 62/100
# 764/764 [==============================] - 1s 1ms/step - loss: 116.1555
# Epoch 63/100
# 764/764 [==============================] - 1s 1ms/step - loss: 108.1449
# Epoch 64/100
# 764/764 [==============================] - 1s 1ms/step - loss: 101.0263
# Epoch 65/100
# 764/764 [==============================] - 1s 1ms/step - loss: 94.7692
# Epoch 66/100
# 764/764 [==============================] - 1s 1ms/step - loss: 89.3337
# Epoch 67/100
# 764/764 [==============================] - 1s 1ms/step - loss: 84.6729
# Epoch 68/100
# 764/764 [==============================] - 1s 1ms/step - loss: 80.7315
# Epoch 69/100
# 764/764 [==============================] - 1s 1ms/step - loss: 77.4464
# Epoch 70/100
# 764/764 [==============================] - 1s 1ms/step - loss: 74.7516
# Epoch 71/100
# 764/764 [==============================] - 1s 1ms/step - loss: 72.5770
# Epoch 72/100
# 764/764 [==============================] - 1s 1ms/step - loss: 70.8543
# Epoch 73/100
# 764/764 [==============================] - 1s 1ms/step - loss: 69.5166
# Epoch 74/100
# 764/764 [==============================] - 1s 1ms/step - loss: 68.5021
# Epoch 75/100
# 764/764 [==============================] - 1s 1ms/step - loss: 67.7543
# Epoch 76/100
# 764/764 [==============================] - 1s 1ms/step - loss: 67.2235
# Epoch 77/100
# 764/764 [==============================] - 1s 1ms/step - loss: 66.8657
# Epoch 78/100
# 764/764 [==============================] - 1s 1ms/step - loss: 66.6397
# Epoch 79/100
# 764/764 [==============================] - 1s 1ms/step - loss: 66.5228
# Epoch 80/100
# 764/764 [==============================] - 1s 1ms/step - loss: 66.4863
# Epoch 81/100
# 764/764 [==============================] - 1s 1ms/step - loss: 66.5273
# Epoch 82/100
# 764/764 [==============================] - 1s 1ms/step - loss: 66.6021
# Epoch 83/100
# 764/764 [==============================] - 1s 1ms/step - loss: 66.7228
# Epoch 84/100
# 764/764 [==============================] - 1s 1ms/step - loss: 66.8604
# Epoch 85/100
# 764/764 [==============================] - 1s 1ms/step - loss: 67.0160
# Epoch 86/100
# 764/764 [==============================] - 1s 1ms/step - loss: 67.1806
# Epoch 87/100
# 764/764 [==============================] - 1s 1ms/step - loss: 67.3547
# Epoch 88/100
# 764/764 [==============================] - 1s 1ms/step - loss: 67.5330
# Epoch 89/100
# 764/764 [==============================] - 1s 1ms/step - loss: 67.7051
# Epoch 90/100
# 764/764 [==============================] - 1s 1ms/step - loss: 67.8732
# Epoch 91/100
# 764/764 [==============================] - 1s 1ms/step - loss: 68.0410
# Epoch 92/100
# 764/764 [==============================] - 1s 1ms/step - loss: 68.2051
# Epoch 93/100
# 764/764 [==============================] - 1s 1ms/step - loss: 68.3655
# Epoch 94/100
# 764/764 [==============================] - 1s 1ms/step - loss: 68.5222
# Epoch 95/100
# 764/764 [==============================] - 1s 1ms/step - loss: 68.6759
# Epoch 96/100
# 764/764 [==============================] - 1s 1ms/step - loss: 68.8313
# Epoch 97/100
# 764/764 [==============================] - 1s 1ms/step - loss: 68.9796
# Epoch 98/100
# 764/764 [==============================] - 1s 1ms/step - loss: 69.1200
# Epoch 99/100
# 764/764 [==============================] - 1s 1ms/step - loss: 69.2549
# Epoch 100/100
# 764/764 [==============================] - 1s 1ms/step - loss: 69.3853

# %%
lstm.save('C:\\Users\\krishna\\Downloads\\RELIANCE(telecom)')
loaded_lstm = load_model('C:\\Users\\krishna\\Downloads\\RELIANCE(telecom)')
loaded_y_pred = loaded_lstm.predict(X_test)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\krishna\Downloads\RELIANCE(telecom)\assets
# INFO:tensorflow:Assets written to: C:\Users\krishna\Downloads\RELIANCE(telecom)\assets
# 20/20 [==============================] - 0s 1ms/step

# %%
# LSTM Prediction
y_pred= lstm.predict(X_test)
# Out:
# 20/20 [==============================] - 0s 1ms/step

# %%
# Predicted vsTrue Adj Close value - LSTM

plt.plot(y_test, label='True Value')
plt.plot(y_pred, label='LSTM Value')
plt.title("Prediction by LSTM")
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.gca().yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))
plt.legend()
plt.show()
